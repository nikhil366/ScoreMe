# %% [markdown]
# # From tabula lib Convert pdf to json

# %%
import tabula
import numpy as np
import pandas as pd
import json

# %%
# conversion of pdf to json via tabula
tabula.read_pdf("tst_json.pdf", output_format="json")
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Got stderr: May 27, 2021 1:26:09 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font ArialMT for base font Symbol
# May 27, 2021 1:26:09 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font ArialMT for base font ZapfDingbats
# [{'extraction_method': 'stream',
#   'top': 41.0,
#   'left': 27.0,
#   'width': 539.0,
#   'height': 733.0,
#   'right': 566.0,
#   'bottom': 774.0,
#   'data': [[{'top': 42.65,
#      'left': 96.47,
#      'width': 65.52000427246094,
#      'height': 4.159999847412109,
#      'text': 'Salary / Pension'}],
#    [{'top': 50.25,
#      'left': 154.48,
#      'width': 286.30999755859375,
#      'height': 5.400000095367432,
#      'text': 'ITR-1 SAHAJ INDIVIDUAL INCOME TAX RETURN'}],
#    [{'top': 71.25,
#      'left': 105.16,
#      'width': 384.9499816894531,
#      'height': 4.5,
# ...

# %%
try:
   df = tabula.read_pdf("tst_json.pdf",multiple_tables=True,stream=True, pages=5,output_format="json")
   print(df)
except:
    print("file not found")
# Out:
# Got stderr: May 27, 2021 1:36:07 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font ArialMT for base font Symbol
# May 27, 2021 1:36:07 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font ArialMT for base font ZapfDingbats
#
# ...

# %% [markdown]
# # Output in Json Format

# %%
print(final_jsn)
with open('pdf2.json', 'w') as json_file:
  json.dump(final_jsn, json_file, indent = 4, sort_keys=True)
# Out:
# [
#     {
#         "bottom": 590.0,
#         "data": [
#             [
#                 {
#                     "height": 3.5999999046325684,
#                     "left": 46.16,
#                     "text": "S No. Name of",
#                     "top": 51.08,
#                     "width": 77.85000610351562
#                 },
#                 {
#                     "height": 3.5999999046325684,
#                     "left": 149.88,
#                     "text": "Address",
#                     "top": 51.08,
#                     "width": 27.220001220703125
#                 },
#                 {
#                     "height": 3.5999999046325684,
#                     "left": 195.29,
#                     "text": "City or Town",
#                     "top": 51.08,
#                     "width": 44.11000061035156
#                 },
#                 {
#                     "height": 3.5999999046325684,
#                     "left": 253.26,
# ...
